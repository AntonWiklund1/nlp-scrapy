# %%
import pandas as pd

# %%
data = pd.read_csv('../data/scraped/bbc_articles.csv')
data
# Out:
#       id                                                url  \
# 0      1     https://www.bbc.com/news/articles/c14kggkr4vro
# 1      2  https://www.bbc.com/future/article/20240404-wh...
# 2      3       https://www.bbc.com/news/technology-68718291
# 3      4       https://www.bbc.com/news/technology-68730138
# 4      5       https://www.bbc.com/news/technology-68722542
# ..   ...                                                ...
# 365  366     https://www.bbc.com/news/world-europe-68778338
# 366  367     https://www.bbc.com/news/world-europe-68803936
# 367  368               https://www.bbc.com/news/uk-68795603
# 368  369     https://www.bbc.com/news/world-europe-68788110
# 369  370     https://www.bbc.com/news/world-europe-68788148
#
#                                               headline  \
# 0           Tesla to settle over fatal Autopilot crash
# 1               Why we have co-evolved with technology
# 2    X gives free blue ticks to its most popular users
# ...

# %%
data.rename(columns={'category': 'Category'}, inplace=True)

# %%
# print the unique values in the category column and the counts of each
print(data['Category'].value_counts())
# Out:
# Category
# politics         138
# entertainment     79
# business          77
# tech              76
# Name: count, dtype: int64

# %%
#save the data to a new csv file
data.to_csv('../data/scraped/bbc_articles.csv', index=False)

# %%
train_data = pd.read_csv('../data/bbc_news_train.csv')
train_data
# Out:
#                                                    Text       Category
# 0     Elon Musk, Amber Heard Something's Fishy On Wr...  entertainment
# 1     Jared Fogle Shut Down By Judge In Bid for Earl...  entertainment
# 2     Credit...Jim Wilson/The New York TimesJune 30,...       politics
# 3     Before Coming Out, a Hard Time Growing UpVideo...          sport
# 4     Fortnites parent company, Epic Games, had brok...           tech
# ...                                                 ...            ...
# 5908  cars pull down us retail figures us retail sal...       business
# 5909  kilroy unveils immigration policy ex-chatshow ...       politics
# 5910  rem announce new glasgow concert us band rem h...  entertainment
# 5911  how political squabbles snowball it s become c...       politics
# 5912  souness delight at euro progress boss graeme s...          sport
#
# [5913 rows x 2 columns]

# %%
train_data['Category'].value_counts()
# Out:
# Category
# sport            1311
# business         1307
# entertainment    1144
# politics         1133
# tech             1018
# Name: count, dtype: int64
