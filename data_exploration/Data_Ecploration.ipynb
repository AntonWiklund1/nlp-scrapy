# %%
import pandas as pd

# %%
# Read the data from the CSV file
data = pd.read_csv('../results/news_enriched.csv')
data
# Out:
#     predicted_category       Category sentiment  \
# 0             politics       politics   Neutral
# 1             politics       politics  Negative
# 2        entertainment  entertainment  Positive
# 3        entertainment  entertainment  Negative
# 4             politics       politics   Neutral
# ..                 ...            ...       ...
# 295               tech           tech  Positive
# 296           politics       politics  Negative
# 297           business       business  Negative
# 298           politics           tech  Negative
# 299           politics       business   Neutral
#
#                                               entities  \
# 0    ['BAE Systems', 'the Wales Peace Coalition', '...
# 1                                                   []
# 2           ['Rio', 'Nothing Really Matters', 'Vogue']
# 3    ['Lidl', 'Cheltenham', "the Cheltenham Civic S...
# 4    ['Sophie', 'the Royal Family', 'the Foreign Of...
# ...

# %%
pd.set_option('display.max_colwidth', None)
data.iloc[84]
# Out:
# predicted_category                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# ...

# %%
pd.reset_option('display.max_colwidth')

# %%
# Get the rows where the sentiment is positive
data[data['sentiment'] == 'Positive']
# Out:
#     predicted_category       Category sentiment  \
# 6        entertainment  entertainment  Positive
# 11       entertainment  entertainment  Positive
# 24                tech           tech  Positive
# 31       entertainment  entertainment  Positive
# 37       entertainment  entertainment  Positive
# 60       entertainment  entertainment  Positive
# 70       entertainment  entertainment  Positive
# 98                tech           tech  Positive
# 100           business       business  Positive
# 103               tech           tech  Positive
# 106           business       business  Positive
# 113               tech           tech  Positive
# 122      entertainment  entertainment  Positive
# 165      entertainment  entertainment  Positive
# 172      entertainment  entertainment  Positive
# 196      entertainment  entertainment  Positive
# 202               tech       business  Positive
# 203           politics       business  Positive
# ...

# %%
# Get the rows where the sentiment is negative
data[data['sentiment'] == 'Negative']
# Out:
#     predicted_category       Category sentiment  \
# 4             politics       politics  Negative
# 7             politics       politics  Negative
# 8             business           tech  Negative
# 9             politics       politics  Negative
# 12       entertainment  entertainment  Negative
# ..                 ...            ...       ...
# 275           business           tech  Negative
# 277               tech  entertainment  Negative
# 281           politics       business  Negative
# 283           business       business  Negative
# 291           politics       politics  Negative
#
#                                               entities  \
# 4    ['pawel k', 'rzeszow-jasionka airport', 'u', '...
# 7    ['po university paris', 'panthéon', 'protest f...
# 8    ['Tesla', 'deutsche bank', 'tesla', 'tesla', '...
# 9    ['green party', 'bristol', 'hamas', 'green par...
# 12   ['Lidl', 'cirencester road', 'bbc', 'lidl', "d...
# ...

# %%
# Get the rows where the sentiment is neutral
data[data['sentiment'] == 'Neutral']
# Out:
#     predicted_category       Category sentiment  \
# 0             politics       politics   Neutral
# 1        entertainment  entertainment   Neutral
# 2        entertainment  entertainment   Neutral
# 3        entertainment  entertainment   Neutral
# 5        entertainment  entertainment   Neutral
# ..                 ...            ...       ...
# 295           politics  entertainment   Neutral
# 296      entertainment       business   Neutral
# 297           business  entertainment   Neutral
# 298               tech           tech   Neutral
# 299           politics       business   Neutral
#
#                                               entities  \
# 0                                                   []
# 1    ['Freddie Mercury', 'freddie mercury', 'crest'...
# 2                                           ['brydon']
# 3    ['gwen', 'terraced home', 'bristol channel', '...
# 5    ['bbc', 'manchester', 'uk chart company', 'man...
# ...

# %%
# sort by rows where the keyword_similarity is high
data.sort_values(by='keyword_similarity', ascending=False).head(10)
# Out:
#     predicted_category       Category sentiment  \
# 292           business           tech  Negative
# 294           business           tech   Neutral
# 299           politics           tech  Negative
# 268           business           tech  Negative
# 121      entertainment  entertainment  Positive
# 31            politics       politics  Negative
# 165           business       business   Neutral
# 174      entertainment       politics   Neutral
# 128               tech           tech   Neutral
# 213           politics  entertainment  Negative
#
#                                               entities  \
# 292                                 ['SeaFood Global']
# 294  ['Methane', 'MethaneSat', 'Methane', 'MethaneS...
# 299  ['Unregulated Oil Extraction Triggers', 'Petro...
# 268     ['Chemical', 'AgroChem Co.', "AgroChem Co.'s"]
# 121  ['The Knepp Estate', 'Knepp Dawn', 'Knepp', 'B...
# 31   ['CWC', 'Kremlin', 'CWC', 'The Organisation fo...
# ...

# %%
data
# Out:
#     predicted_category       Category sentiment  \
# 0             politics       politics   Neutral
# 1        entertainment  entertainment   Neutral
# 2        entertainment  entertainment   Neutral
# 3        entertainment  entertainment   Neutral
# 4             politics       politics  Negative
# ..                 ...            ...       ...
# 295           politics  entertainment   Neutral
# 296      entertainment       business   Neutral
# 297           business  entertainment   Neutral
# 298               tech           tech   Neutral
# 299           politics       business   Neutral
#
#                                               entities  \
# 0                                                   []
# 1    ['Freddie Mercury', 'freddie mercury', 'crest'...
# 2                                           ['brydon']
# 3    ['gwen', 'terraced home', 'bristol channel', '...
# 4    ['pawel k', 'rzeszow-jasionka airport', 'u', '...
# ...

# %%
data[data['Top_10'] == True].sort_values(by='keyword_similarity', ascending=True).head(10)
# Out:
#     predicted_category       Category sentiment  \
# 213           politics  entertainment  Negative
# 128               tech           tech   Neutral
# 174      entertainment       politics   Neutral
# 165           business       business   Neutral
# 31            politics       politics  Negative
# 121      entertainment  entertainment  Positive
# 268           business           tech  Negative
# 299           politics           tech  Negative
# 294           business           tech   Neutral
# 292           business           tech  Negative
#
#                                               entities  \
# 213  ['BBC', '399bn', 'ALQST', 'BBC', 'al-Khuraybah...
# 128  ['the National Grid', 'National Grid', 'Linked...
# 174  ['Newcastle University', 'Aladdin', 'Disney', ...
# 165  ['Thames Water', 'Thames Water', 'Regulator Of...
# 31   ['CWC', 'Kremlin', 'CWC', 'The Organisation fo...
# 121  ['The Knepp Estate', 'Knepp Dawn', 'Knepp', 'B...
# ...

# %%
pd.set_option('display.max_colwidth', None)

data.iloc[121]
# Out:
# predicted_category                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# ...

# %%
pd.reset_option('display.max_colwidth')

# %%
data[data['Top_10'] == True].sort_values(by='keyword_similarity',
# Out:
#     predicted_category       Category sentiment  \
# 32            politics       politics  Negative
# 121      entertainment  entertainment  Positive
# 128               tech           tech   Neutral
# 165           business       business   Neutral
# 174      entertainment       politics   Neutral
# 213           politics  entertainment  Negative
# 215           politics       politics  Negative
# 219           politics           tech  Negative
# 250           business       business   Neutral
# 294           business           tech   Neutral
#
#                                               entities  \
# 32   ['CWC', 'Kremlin', 'CWC', 'The Organisation fo...
# 121  ['The Knepp Estate', 'Knepp Dawn', 'Knepp', 'B...
# 128  ['the National Grid', 'National Grid', 'Linked...
# 165  ['Thames Water', 'Thames Water', 'Regulator Of...
# 174  ['Newcastle University', 'Aladdin', 'Disney', ...
# 213  ['BBC', '399bn', 'ALQST', 'BBC', 'al-Khuraybah...
# ...

# %%
data[data['url'] == 'https://news.example.com/environment/oil-spill-arctic-2024']
# Out:
#     predicted_category  Category sentiment                        entities  \
# 215           politics  politics  Negative  ['PetroGlobal', 'PetroGlobal']
#
#                                              headline  \
# 215  Major Oil Spill Devastates Arctic Ocean Wildlife
#
#                                                    url        time  \
# 215  https://news.example.com/environment/oil-spill...  2024-04-01
#
#      keyword_similarity  scandal  Top_10 most_similar_keyword  \
# 215            0.418194  Scandal    True  Habitat destruction
#
#                                                   body
# 215  In a devastating turn of events, the Arctic Oc...
